# %% [markdown]
# # Test building opt

# %% [markdown]
# Import all relevant modules

# %%
import os
import time
import pandas as pd
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import tsib
import tsib.buildingopt as bopt
import tsib.buildingmanager as bm
import tsib
# Out:
# /home/leander/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:915: MatplotlibDeprecationWarning: nbagg.transparent is deprecated and ignored. Use figure.facecolor instead.
#   mplDeprecation)

# %%
import copy

# %%
import enercore.results as res

# %%
import matplotlib.pyplot as plt

# %%
VARIANT = 'default_2016'

# %% [markdown]
# ### 1. Initialize the variation dictionary

# %%
startTime = time.time()

# %% [markdown]
# Init the building manager

# %%
boptmanager = bm.BuildingOptManager(datapath = os.path.join('testresults', 
                                               'buildingresults'),)

# %% [markdown]
# Get two building configurations

# %%
boptList = []

# %%
sfh = tsib.BuildingConfiguration( {'ID':'DE.N.SFH.09.Gen.ReEx.001.001',
                                  'costdata': VARIANT,
                                  'ownership': True, 
                                  'longitude': 11.,
                                  'latitude':51.},)
boptList.append(bopt.BuildingOpt(configurator = sfh), )
# Out:
# /media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/tsib/tsib/buildingconfig.py:278: UserWarning: number of persons. "n_persons" is inherited from IWU
#   warnings.warn('number of persons. "n_persons" is inherited from IWU')
# /media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/tsib/tsib/buildingconfig.py:284: UserWarning: number of app. "n_apartments" is inherited from IWU
#   warnings.warn('number of app. "n_apartments" is inherited from IWU')

# %% [markdown]
# mfh = tsib.BuildingConfiguration( {'ID':'DE.East.AB.07.Gen.ReEx.001.001',
#                                    'costdata': VARIANT,
#                                  'ownership': False, 'longitude': 7.,
#                                  'latitude':51.},)
# boptList.append(bopt.BuildingOpt(configurator = mfh), )

# %% [markdown]
# ### 2. Run the optimization

# %%
components = ['FiTPV','Electricity supply','Gas supply', 'Gas boiler', 'HP Tarif','Heat pump',
              'ElectricHeater','Photovoltaic 1', 'Battery']

# %% [markdown]
# Optimize the building list

# %% [markdown]
# Get Reference

# %%
results_ref = boptmanager.getOpti(boptList, case = 'refCost')
# Out:
# Duration for getting the results: 73.60939431190491
# /media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/tsib/tsib/buildingmanager.py:241: UserWarning: Traceback (most recent call last):
#   File "/home/leander/anaconda3/lib/python3.6/site-packages/pyomo/solvers/plugins/solvers/gurobi_direct.py", line 244, in _set_instance
#     self._solver_model = self._gurobipy.Model(model.name)
# AttributeError: 'GurobiPersistent' object has no attribute '_gurobipy'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/tsib/tsib/buildingmanager.py", line 287, in optiTask
#     result = bdgOptObj.refCost(threads=1)
#   File "/media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/tsib/tsib/buildingopt.py", line 948, in refCost
#     TSA = False, threads = threads)
#   File "/media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/tsib/tsib/buildingopt.py", line 891, in doOpt
#     optStatus = self.nw.optModel(solver=solver, tee=tee, solverOpt=solverOpt)
#   File "/media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/enercore/enercore/energysystem.py", line 800, in optModel
#     self.solver.set_instance(self.M)
#   File "/home/leander/anaconda3/lib/python3.6/site-packages/pyomo/solvers/plugins/solvers/persistent_solver.py", line 80, in set_instance
#     return self._set_instance(model, kwds)
#   File "/home/leander/anaconda3/lib/python3.6/site-packages/pyomo/solvers/plugins/solvers/gurobi_direct.py", line 253, in _set_instance
#     raise Exception(msg)
# Exception: Unable to create Gurobi model. Have you installed the Python bindings for Gurboi?
#
# 	Error message: 'GurobiPersistent' object has no attribute '_gurobipy'
#
#   warnings.warn(result[1], UserWarning)

# %%
boptList[0].cfg
# Out:
# {'n_apartments': 1,
#  'A_ref': 121.88,
#  'n_Storey': 1,
#  'h_room': 2.5,
#  'A_Window_North': 5.0,
#  'A_Window_East': 3.6,
#  'A_Window_South': 20.26,
#  'A_Window_West': 3.6,
#  'A_Window_Horizontal': 0.0,
#  'A_Window': 32.46,
#  'F_sh_vert': 0.6,
#  'F_sh_hor': 0.8,
#  'F_f': 0.3,
#  'F_w': 0.9,
#  'A_Wall_1': 126.6,
#  'A_Wall_2': 0.0,
#  'A_Wall_3': 0.0,
#  'A_Roof_1': 115.5,
#  'A_Roof_2': 0.0,
#  'A_Floor_1': 84.3076,
#  'A_Floor_2': 0.0,
#  'A_Door_1': 2.0,
#  'roofTilt': 45.0,
#  'roofOrientation': 135.0,
#  'U_Window': 1.9,
#  'g_gl_n_Window': 0.6,
#  'U_Wall_1': 0.3,
#  'b_Transmission_Wall_1': 1,
#  'U_Wall_2': 0.3,
#  'b_Transmission_Wall_2': 0.0,
#  'U_Wall_3': 0.3,
#  'b_Transmission_Wall_3': 0.0,
#  'U_Roof_1': 0.35,
#  'b_Transmission_Roof_1': 1,
#  'U_Roof_2': 0.3,
#  'b_Transmission_Roof_2': 0,
#  'U_Door_1': 2.0,
#  'U_Floor_1': 0.39647577100000003,
#  'b_Transmission_Floor_1': 0.5,
#  'U_Floor_2': 0.45,
#  'b_Transmission_Floor_2': 0.0,
#  'n_air_infiltration': 0.2,
#  'n_air_use': 0.4,
#  'buildingYear': 2001,
#  'thermalClass': 'medium',
#  'refurbishment': True,
#  'force_refurbishment': False,
#  'latitude': 51.0,
#  'longitude': 11.0,
#  'weather':                            RG  IS  MM  DD  HH  N   WR   WS    T      p  \
#  2010-01-01 00:30:00+01:00   9   1   1   1   1  3  200  3.1 -3.6  969.1
#  2010-01-01 01:30:00+01:00   9   1   1   1   2  1  160  2.4 -4.8  966.6
#  2010-01-01 02:30:00+01:00   9   1   1   1   3  0  160  2.4 -5.8  964.5
#  2010-01-01 03:30:00+01:00   9   1   1   1   4  1  190  2.2 -5.7  963.8
#  2010-01-01 04:30:00+01:00   9   1   1   1   5  2  130  2.5 -5.7  963.0
#  2010-01-01 05:30:00+01:00   9   1   1   1   6  4  170  2.0 -5.0  962.2
#  2010-01-01 06:30:00+01:00   9   1   1   1   7  5  160  3.0 -5.2  961.5
#  2010-01-01 07:30:00+01:00   9   1   1   1   8  6  170  3.0 -3.5  961.0
#  2010-01-01 08:30:00+01:00   9   1   1   1   9  7  180  5.0 -2.7  960.5
#  2010-01-01 09:30:00+01:00   9   1   1   1  10  7  190  5.0 -0.9  959.9
#  2010-01-01 10:30:00+01:00   9   1   1   1  11  6  160  7.0 -0.3  959.2
#  2010-01-01 11:30:00+01:00   9   1   1   1  12  6  170  6.0  1.2  958.1
#  2010-12-31 14:30:00+01:00   39   17.032059
#  2010-12-31 15:30:00+01:00    8    0.000000
#  2010-12-31 16:30:00+01:00    0    0.000000
#  2010-12-31 17:30:00+01:00    0    0.000000
#  2010-12-31 18:30:00+01:00    0    0.000000
#  2010-12-31 19:30:00+01:00    0    0.000000
#  2010-12-31 20:30:00+01:00    0    0.000000
#  2010-12-31 21:30:00+01:00    0    0.000000
#  2010-12-31 22:30:00+01:00    0    0.000000
#  2010-12-31 23:30:00+01:00    0    0.000000
#
#  [8760 rows x 21 columns],
#  'design_T_min': -14,
#  'weatherID': 'TRY_9',
#  'nightReduction': True,
#  'occControl': False,
#  'capControl': True,
#  'comfortT_lb': 21.0,
#  'comfortT_ub': 24.0,
#  'n_persons': 3,
#  'hasFirePlace': True,
#  'fireplaceSize': 10.0,
#  'varyoccupancy': 1,
#  'mean_load': False,
#  'Q_ig': array([0.31922863, 0.31922863, 0.31922863, ..., 0.57137932, 0.60890419,
#         0.6790143 ]),
#  'occ_nothome': 2010-01-01 00:00:00    0.000000
#  2010-01-01 01:00:00    0.000000
#  2010-01-01 02:00:00    0.000000
#  2010-01-01 03:00:00    0.000000
#  2010-01-01 04:00:00    0.000000
#  2010-01-01 05:00:00    0.000000
#  2010-01-01 06:00:00    0.000000
#  2010-01-01 07:00:00    0.000000
#  2010-01-01 08:00:00    0.666667
#  2010-01-01 09:00:00    0.666667
#  2010-01-01 10:00:00    0.666667
#  2010-01-01 11:00:00    0.666667
#  2010-01-01 12:00:00    0.333333
#  2010-01-01 13:00:00    0.666667
#  2010-01-01 14:00:00    1.000000
#  2010-01-01 15:00:00    0.666667
#  2010-01-01 16:00:00    0.333333
#  2010-01-01 17:00:00    0.333333
#  2010-01-01 18:00:00    0.000000
#  2010-01-01 19:00:00    0.666667
#  2010-01-01 20:00:00    1.000000
#  2010-01-01 21:00:00    0.000000
#  2010-01-01 22:00:00    0.000000
#  2010-01-01 23:00:00    0.000000
#  2010-01-02 00:00:00    0.000000
#  2010-01-02 01:00:00    0.000000
#  2010-01-02 02:00:00    0.000000
#  2010-01-02 03:00:00    0.000000
#  2010-01-02 04:00:00    0.000000
#  2010-01-02 05:00:00    0.000000
#                           ...
#  2010-12-30 18:00:00    0.000000
#  2010-12-30 19:00:00    0.000000
#  2010-12-30 20:00:00    0.000000
#  2010-12-30 21:00:00    0.333333
#  2010-12-30 22:00:00    0.333333
#  2010-12-30 23:00:00    0.333333
#  2010-12-31 00:00:00    0.333333
#  2010-12-31 01:00:00    0.333333
#  2010-12-31 02:00:00    0.333333
#  2010-12-31 03:00:00    0.333333
#  2010-12-31 04:00:00    0.333333
#  2010-12-31 05:00:00    0.333333
#  2010-12-31 06:00:00    0.333333
#  2010-12-31 07:00:00    0.333333
#  2010-12-31 08:00:00    1.000000
#  2010-12-31 09:00:00    1.000000
#  2010-12-31 10:00:00    1.000000
#  2010-12-31 11:00:00    1.000000
#  2010-12-31 12:00:00    1.000000
#  2010-12-31 13:00:00    1.000000
#  2010-12-31 14:00:00    1.000000
#  2010-12-31 15:00:00    1.000000
#  2010-12-31 16:00:00    1.000000
#  2010-12-31 17:00:00    0.666667
#  2010-12-31 18:00:00    0.000000
#  2010-12-31 19:00:00    0.333333
#  2010-12-31 20:00:00    0.333333
#  2010-12-31 21:00:00    0.333333
#  2010-12-31 22:00:00    0.333333
#  2010-12-31 23:00:00    0.000000
#  Length: 8760, dtype: float64,
#  'occ_sleeping': 2010-01-01 00:00:00    1.000000
#  2010-01-01 01:00:00    1.000000
#  2010-01-01 02:00:00    1.000000
#  2010-01-01 03:00:00    1.000000
#  2010-01-01 04:00:00    1.000000
#  2010-01-01 05:00:00    1.000000
#  2010-01-01 06:00:00    0.666667
#  2010-01-01 07:00:00    0.333333
#  2010-01-01 08:00:00    0.000000
#  2010-01-01 09:00:00    0.000000
#  2010-01-01 10:00:00    0.000000
#  2010-01-01 11:00:00    0.000000
#  2010-01-01 12:00:00    0.000000
#  2010-01-01 13:00:00    0.000000
#  2010-01-01 14:00:00    0.000000
#  2010-01-01 15:00:00    0.000000
#  2010-01-01 16:00:00    0.000000
#  2010-01-01 17:00:00    0.000000
#  2010-01-01 18:00:00    0.000000
#  2010-01-01 19:00:00    0.000000
#  2010-01-01 20:00:00    0.000000
#  2010-01-01 21:00:00    0.000000
#  2010-01-01 22:00:00    0.333333
#  2010-01-01 23:00:00    0.333333
#  2010-01-02 00:00:00    1.000000
#  2010-01-02 01:00:00    1.000000
#  2010-01-02 02:00:00    1.000000
#  2010-01-02 03:00:00    1.000000
#  2010-01-02 04:00:00    1.000000
#  2010-01-02 05:00:00    1.000000
#                           ...
#  2010-12-30 18:00:00    0.000000
#  2010-12-30 19:00:00    0.000000
#  2010-12-30 20:00:00    0.000000
#  2010-12-30 21:00:00    0.000000
#  2010-12-30 22:00:00    0.000000
#  2010-12-30 23:00:00    0.666667
#  2010-12-31 00:00:00    0.666667
#  2010-12-31 01:00:00    0.666667
#  2010-12-31 02:00:00    0.666667
#  2010-12-31 03:00:00    0.666667
#  2010-12-31 04:00:00    0.666667
#  2010-12-31 05:00:00    0.666667
#  2010-12-31 06:00:00    0.666667
#  2010-12-31 07:00:00    0.333333
#  2010-12-31 08:00:00    0.000000
#  2010-12-31 09:00:00    0.000000
#  2010-12-31 10:00:00    0.000000
#  2010-12-31 11:00:00    0.000000
#  2010-12-31 12:00:00    0.000000
#  2010-12-31 13:00:00    0.000000
#  2010-12-31 14:00:00    0.000000
#  2010-12-31 15:00:00    0.000000
#  2010-12-31 16:00:00    0.000000
#  2010-12-31 17:00:00    0.000000
#  2010-12-31 18:00:00    0.000000
#  2010-12-31 19:00:00    0.000000
#  2010-12-31 20:00:00    0.000000
#  2010-12-31 21:00:00    0.000000
#  2010-12-31 22:00:00    0.000000
#  2010-12-31 23:00:00    0.666667
#  Name: OccNotActive, Length: 8760, dtype: float64,
#  2010-01-01 12:00:00    0.000000
#  2010-01-01 13:00:00    0.000000
#  2010-01-01 14:00:00    0.000000
#  2010-01-01 15:00:00    0.000000
#  2010-01-01 16:00:00    2.283770
#  2010-01-01 17:00:00    0.000000
#  2010-01-01 18:00:00    2.283770
#  2010-01-01 19:00:00    0.000000
#  2010-01-01 20:00:00    0.000000
#  2010-01-01 21:00:00    0.000000
#  2010-01-01 22:00:00    2.283770
#  2010-01-01 23:00:00    0.000000
#  2010-01-02 00:00:00    0.000000
#  2010-01-02 01:00:00    0.000000
#  2010-01-02 02:00:00    0.000000
#  2010-01-02 03:00:00    0.000000
#  2010-01-02 04:00:00    0.000000
#  2010-01-02 05:00:00    0.000000
#                           ...
#  2010-12-30 18:00:00    0.000000
#  2010-12-30 19:00:00    0.000000
#  2010-12-30 20:00:00    0.000000
#  2010-12-30 21:00:00    0.000000
#  2010-12-30 22:00:00    0.000000
#  2010-12-30 23:00:00    0.000000
#  2010-12-31 00:00:00    0.000000
#  2010-12-31 01:00:00    0.000000
#  2010-12-31 02:00:00    0.000000
#  2010-12-31 03:00:00    0.000000
#  2010-12-31 04:00:00    0.000000
#  2010-12-31 05:00:00    0.000000
#  2010-12-31 06:00:00    0.000000
#  2010-12-31 07:00:00    0.000000
#  2010-12-31 08:00:00    0.000000
#  2010-12-31 09:00:00    0.000000
#  2010-12-31 10:00:00    0.000000
#  2010-12-31 11:00:00    0.000000
#  2010-12-31 12:00:00    0.000000
#  2010-12-31 13:00:00    0.000000
#  2010-12-31 14:00:00    0.000000
#  2010-12-31 15:00:00    0.000000
#  2010-12-31 16:00:00    0.000000
#  2010-12-31 17:00:00    0.000000
#  2010-12-31 18:00:00    0.000000
#  2010-12-31 19:00:00    0.000000
#  2010-12-31 20:00:00    0.000000
#  2010-12-31 21:00:00    0.000000
#  2010-12-31 22:00:00    2.283770
#  2010-12-31 23:00:00    6.229047
#  Name: HotWater, Length: 8760, dtype: float64,
#  'n_occupants': 3,
#  'fireplaceLoad': 0
#  2009-12-31 23:30:00    0.000000e+00
#  2010-01-01 00:30:00    0.000000e+00
#  2010-01-01 01:30:00    0.000000e+00
#  2010-01-01 02:30:00    0.000000e+00
#  2010-01-01 03:30:00    0.000000e+00
#  2010-01-01 04:30:00    0.000000e+00
#  2010-01-01 05:30:00    0.000000e+00
#  2010-01-01 06:30:00    1.000000e+00
#  2010-01-01 07:30:00    8.000000e-01
#  2010-01-01 08:30:00    1.000000e+00
#  2010-01-01 09:30:00    8.000000e-01
#  2010-01-01 10:30:00    6.000000e-01
#  2010-01-01 11:30:00    4.000000e-01
#  2010-01-01 12:30:00    2.000000e-01
#  2010-01-01 13:30:00    5.551115e-17
#  2010-01-01 14:30:00    0.000000e+00
#  2010-01-01 15:30:00    0.000000e+00
#  2010-01-01 16:30:00    0.000000e+00
#  2010-01-01 17:30:00    1.000000e+00
#  2010-01-01 18:30:00    8.000000e-01
#  2010-01-01 19:30:00    6.000000e-01
#  2010-01-01 20:30:00    1.000000e+00
#  2010-01-01 21:30:00    8.000000e-01
#  2010-01-01 22:30:00    6.000000e-01
#  2010-01-01 23:30:00    4.000000e-01
#  2010-01-02 00:30:00    2.000000e-01
#  2010-01-02 01:30:00    5.551115e-17
#  2010-01-02 02:30:00    0.000000e+00
#  2010-01-02 03:30:00    0.000000e+00
#  2010-01-02 04:30:00    0.000000e+00
#                             ...
#  2010-12-30 17:30:00    0.000000e+00
#  2010-12-30 18:30:00    0.000000e+00
#  2010-12-30 19:30:00    0.000000e+00
#  2010-12-30 20:30:00    0.000000e+00
#  2010-12-30 21:30:00    0.000000e+00
#  2010-12-30 22:30:00    0.000000e+00
#  2010-12-30 23:30:00    0.000000e+00
#  2010-12-31 00:30:00    0.000000e+00
#  2010-12-31 01:30:00    0.000000e+00
#  2010-12-31 02:30:00    0.000000e+00
#  2010-12-31 03:30:00    0.000000e+00
#  2010-12-31 04:30:00    0.000000e+00
#  2010-12-31 05:30:00    0.000000e+00
#  2010-12-31 06:30:00    0.000000e+00
#  2010-12-31 07:30:00    0.000000e+00
#  2010-12-31 08:30:00    0.000000e+00
#  2010-12-31 09:30:00    0.000000e+00
#  2010-12-31 10:30:00    0.000000e+00
#  2010-12-31 11:30:00    0.000000e+00
#  2010-12-31 12:30:00    0.000000e+00
#  2010-12-31 13:30:00    0.000000e+00
#  2010-12-31 14:30:00    0.000000e+00
#  2010-12-31 15:30:00    0.000000e+00
#  2010-12-31 16:30:00    0.000000e+00
#  2010-12-31 17:30:00    1.000000e+00
#  2010-12-31 18:30:00    8.000000e-01
#  2010-12-31 19:30:00    6.000000e-01
#  2010-12-31 20:30:00    4.000000e-01
#  2010-12-31 21:30:00    2.000000e-01
#  2010-12-31 22:30:00    5.551115e-17
#  Name: 1, Length: 8760, dtype: float64,
#  'hotWaterElec': False,
#  'existingHeatSupply': 'Oil boiler',
#  'replaceHeatSupply': True,
#  'hasSolarThermal': False,
#  'hasPhotovoltaic': False,
#  'T_sup': 50,
#  'T_ret': 25.0,
#  'ownership': True,
#  'onlyEnergyInvest': False,
#  'WACC': 0.03,
#  'costdata': 'default_2016'}

# %% [markdown]
# Get min cost

# %%
results_min = boptmanager.getOpti(boptList, case = 'minCost')
# Out:
# Duration for getting the results: 211.56837272644043
# /media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/tsib/tsib/buildingmanager.py:241: UserWarning: Traceback (most recent call last):
#   File "/home/leander/anaconda3/lib/python3.6/site-packages/pyomo/solvers/plugins/solvers/gurobi_direct.py", line 244, in _set_instance
#     self._solver_model = self._gurobipy.Model(model.name)
# AttributeError: 'GurobiPersistent' object has no attribute '_gurobipy'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/tsib/tsib/buildingmanager.py", line 285, in optiTask
#     result = bdgOptObj.minCost(threads=1, CO2price=CO2price)
#   File "/media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/tsib/tsib/buildingopt.py", line 1014, in minCost
#     fullOperation=True, threads = threads)
#   File "/media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/tsib/tsib/buildingopt.py", line 882, in doOpt
#     extConFunc = self._addAdditionalConstraints)
#   File "/media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/enercore/enercore/energysystem.py", line 938, in optFullOperation
#     returnbool = self.optModel(**optKwargs)
#   File "/media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/enercore/enercore/energysystem.py", line 800, in optModel
#     self.solver.set_instance(self.M)
#   File "/home/leander/anaconda3/lib/python3.6/site-packages/pyomo/solvers/plugins/solvers/persistent_solver.py", line 80, in set_instance
#     return self._set_instance(model, kwds)
#   File "/home/leander/anaconda3/lib/python3.6/site-packages/pyomo/solvers/plugins/solvers/gurobi_direct.py", line 253, in _set_instance
#     raise Exception(msg)
# Exception: Unable to create Gurobi model. Have you installed the Python bindings for Gurboi?
#
# 	Error message: 'GurobiPersistent' object has no attribute '_gurobipy'
#
#   warnings.warn(result[1], UserWarning)

# %% [markdown]
# Get min CO2

# %%
results_exist = boptmanager.getOpti(boptList, case = 'minCO2')
# Out:
# /media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/tsib/tsib/buildingmanager.py:196: UserWarning: minCO2 with ID 3 has not optimized reference system
#   " has not optimized reference system")
# Duration for getting the results: 2.459162473678589
# /media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/tsib/tsib/buildingmanager.py:241: UserWarning: Traceback (most recent call last):
#   File "/media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/tsib/tsib/buildingmanager.py", line 289, in optiTask
#     result = bdgOptObj.minCO2(threads=1)
#   File "/media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/tsib/tsib/buildingopt.py", line 1038, in minCO2
#     'referenceCost')
# ValueError: Run first "refCost()" to determine the referenceCost
#
#   warnings.warn(result[1], UserWarning)

# %% [markdown]
# ### 2. Run the optimization

# %% [markdown]
# Plot reference results

# %%
paraResults_ref = res.ParamVarResultManager(paramname = '', colordictionary = bopt.BuildingOpt.COLOR_DICT, 
                                        results = results_ref)
ax = plt.subplot(1,1,1)
paraResults_ref.plotNodeRes(parameters=['Annual Cost'], 
              plottype='bar',ylabel='Annual Cost [eur/a]',stacked=True, linewidth=0, labelrotation=30,
                    showValues = False,ax = ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-9d14bca6f1dc> in <module>()
#       1 paraResults_ref = res.ParamVarResultManager(paramname = '', colordictionary = bopt.BuildingOpt.COLOR_DICT,
# ----> 2                                         results = results_ref)
#       3 ax = plt.subplot(1,1,1)
#       4 paraResults_ref.plotNodeRes(parameters=['Annual Cost'],
#       5               plottype='bar',ylabel='Annual Cost [eur/a]',stacked=True, linewidth=0, labelrotation=30,
#
# /media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/enercore/enercore/results.py in __init__(self, **kwargs)
#     819                     self.addSystem(result=result, paramvalue=params[ii],
#     820                                    updatePandas = False)
# --> 821                 self._toPandas()
#     822         return
#     823
#
# /media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/enercore/enercore/results.py in _toPandas(self)
#     826         Transforms the result data to pandas.DataFrame
#     827         '''
# --> 828         self.flows=pd.concat([result.flows for result in self._reslist], keys=self._paramlist,names=[self._paramname,'Date']).fillna(0.0)
#     829         self.nodes=pd.concat([result.nodes for result in self._reslist], keys=self._paramlist,names=[self._paramname,'Value']).fillna(0.0)
#     830         self.loads=pd.concat([result.loads for result in self._reslist], keys=self._paramlist,names=[self._paramname,'Date']).fillna(0.0)
#
# /media/leander/D24CB5984CB57835/Users/Leander/everken/05_Repositories/enercore/enercore/results.py in <listcomp>(.0)
#     826         Transforms the result data to pandas.DataFrame
#     827         '''
# --> 828         self.flows=pd.concat([result.flows for result in self._reslist], keys=self._paramlist,names=[self._paramname,'Date']).fillna(0.0)
#     829         self.nodes=pd.concat([result.nodes for result in self._reslist], keys=self._paramlist,names=[self._paramname,'Value']).fillna(0.0)
#     830         self.loads=pd.concat([result.loads for result in self._reslist], keys=self._paramlist,names=[self._paramname,'Date']).fillna(0.0)
#
# AttributeError: 'NoneType' object has no attribute 'flows'

# %% [markdown]
# Plot min cost results

# %%
paraResults_min = res.ParamVarResultManager(paramname = '', colordictionary = bopt.BuildingOpt.COLOR_DICT, 
                                        results = results_min)
ax = plt.subplot(1,1,1)
paraResults_min.plotNodeRes(parameters=['Annual Cost'], 
              plottype='bar',ylabel='Annual Cost [eur/a]',stacked=True, linewidth=0, labelrotation=30,
                    showValues = False,ax = ax)

# %% [markdown]
# Plot CO2 min results

# %%
results_exist

# %%
paraResults_CO2 = res.ParamVarResultManager(paramname = '', colordictionary = bopt.BuildingOpt.COLOR_DICT, 
                                        results = results_exist)
ax = plt.subplot(1,1,1)
paraResults_CO2.plotNodeRes(parameters=['Annual Cost'], 
              plottype='bar',ylabel='Annual Cost [eur/a]',stacked=True, linewidth=0, labelrotation=30,
                    showValues = False,ax = ax)

# %% [markdown]
# Show detailed results for the second building

# %%
resu = results_exist[0]

# %%
resu.loads[[col for col in resu.nodes if 'Heat storage' in col]].max()

# %%
resu.loads[[col for col in resu.nodes if 'Heat pump' in col]].max()

# %%
resu.flows[[col for col in resu.flows if 'Heat storage 50.0' in col]].max()

# %%
resu.loads[[col for col in resu.nodes if 'Heat storage' in col]]['20100301':'20100305'].plot(kind ='area')

# %%
resu.nodes[[col for col in resu.nodes if 'Heat storage' in col]]

# %%
resu.showCapacities()

# %%
res = results_a[1]

# %%
res.nodes.columns

# %%
res.flows

# %%
nodename = 'Heat storage'


indict={}
incomplist=[]
outdict={}
outcomplist=[]

for column in res.flows.columns:
    FromTo=column.split(' to ')
    if nodename in FromTo[0] and not nodename in FromTo[1]:
                    # drop zero columns
        if (res.flows[column] > 0).any():
            outdict[FromTo[1]]=res.flows[column].values
#                   fulldict[FromTo[1]]=-self.flows[column].values
            outcomplist.append(FromTo[1])
#                   fullcomplist.append(FromTo[1])
    elif nodename in FromTo[1] and not nodename in FromTo[0]:
        if (res.flows[column] > 0).any():
            indict[FromTo[0]]=res.flows[column].values
#                   fulldict[FromTo[0]]=self.flows[column].values
            incomplist.append(FromTo[0])

# %%
incomplist

# %%
outcomplist

# %%
res.nodes['Heat storage']

# %%
'Heat storage 75.0'

# %%
res.nodes.columns

# %%
res.loads['Heat storage 75.0'].plot()

# %%
incomplist

# %%
outcomplist

# %%
res.flows['HNode 50.0 to Heat storage 50.0']

# %%
boptList[1].nw?

# %%
boptList[1]._initTechSystem()

# %%
nw = boptList[1].nw

# %%
nw.getNode('Heat storage 50.0')

# %%
boptList[1].nw.draw(iconScale = 0.1,)

# %%
import networkx

# %%
networkx.draw?

# %%
networkx.draw(nw)
