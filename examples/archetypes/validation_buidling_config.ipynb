# %% [markdown]
# # Validation of the tsib.buildingconfig
# Author: Leander Kotzur
#
# Date: 21.09.2019

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import tsib.buildingconfig as cfg
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import copy
import os

# %% [markdown]
# ## Read profile data

# %% [markdown]
# Building configurations

# %%
bdg_cfgs = pd.read_csv(os.path.join('25_Archetypes.csv'), index_col = 0)

# %%
kwgs['latitude'] = kwgs['latitude'] + 54.
kwgs['longitude'] = kwgs['longitude'] + 8.

# %%
bdg_cfgs
# Out:
#     buildingYear  a_ref_app surrounding  n_persons  roofOrientation  \
# 0           1919       79.0    Terraced          1              0.0
# 1           1959       99.0    Detached          1             45.0
# 2           1969       79.0        Semi          2             67.5
# 3           1987       79.0        Semi          3             45.0
# 4           1949      139.0        Semi          2             45.0
# 5           1969       99.0    Detached          1             22.5
# 6           1959      119.0    Terraced          4             45.0
# 7           1919       79.0    Detached          2             90.0
# 8           1995      119.0    Detached          4             90.0
# 9           1959      119.0    Detached          4             67.5
# 10          1949      250.0    Detached          1             22.5
# 11          1959      159.0        Semi          5             22.5
# 12          2001       59.0    Detached          2             45.0
# 13          1959       59.0    Terraced          3             67.5
# 14          2001       39.0        Semi          1             22.5
# 15          1979       59.0    Terraced          2             90.0
# 16          2009      179.0        Semi          5             45.0
# 17          1959      139.0        Semi          2             22.5
# 18          1949       39.0    Terraced          3             67.5
# 19          1949       59.0    Terraced          2             67.5
# 20          1969       59.0    Terraced          2             67.5
# 21          1979       99.0    Terraced          1             45.0
# 22          1995      139.0    Detached          2              0.0
# 23          1987       99.0        Semi          0             67.5
# 24          1949       79.0        Semi          0             45.0
#
#     ownership  buildnew  hasPhotovoltaic existingHeatSupply  longitude  \
# 0        True     False                0         Oil boiler   0.485854
# 1        True     False                0    Electric heater   0.218793
# 2        True      True                1                CHP   0.366913
# 3        True     False                0         Oil boiler   0.304921
# 4        True     False                0         Gas boiler   0.146924
# 5        True      True                1         Oil boiler   0.309201
# 6        True      True                0         Oil boiler   0.361066
# 7        True     False                1                CHP   0.575275
# 8        True     False                0         Gas boiler   0.605736
# 9        True     False                0         Gas boiler   0.303204
# 10       True      True                0   District heating   0.519689
# 11       True      True                0         Gas boiler   0.357501
# 12       True     False                0         Gas boiler   0.461129
# 13       True     False                0         Gas boiler   0.572526
# 14       True     False                0   District heating   0.345838
# 15       True     False                0         Gas boiler   0.242833
# 16       True      True                0      Pellet boiler   0.340934
# 17       True     False                0    Electric heater   0.583783
# 18       True      True                1         Gas boiler   0.483329
# 19       True     False                0   District heating   0.642166
# 20       True      True                0                CHP   0.496569
# 21       True      True                0         Gas boiler   0.466009
# 22       True     False                0         Oil boiler   0.390359
# 23       True      True                0         Gas boiler   0.592902
# 24       True     False                1                CHP   0.310548
#
#     latitude  n_apartments
# 0   0.502379            11
# 1   0.430747            20
# 2   0.582369            50
# 3   0.360978             5
# 4   0.483464             9
# 5   0.399318             8
# 6   0.336989             9
# 7   0.483873            15
# 8   0.631321             1
# 9   0.362912             1
# 10  0.507313             1
# 11  0.457889             1
# 12  0.616089             1
# 13  0.657562             1
# 14  0.298995             1
# 15  0.397697             1
# 16  0.343957             1
# 17  0.638122             2
# 18  0.458074            42
# 19  0.454986            25
# 20  0.482417            31
# 21  0.484783             6
# 22  0.368084             1
# 23  0.469747            18
# 24  0.459091           201
